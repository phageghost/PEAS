# %%
import os
import numpy, scipy, pandas
import matplotlib
import matplotlib.pyplot as plt
from imp import reload
import seaborn

# %%
bed_fname = '/home/dskola/projects/coupled_peaks/moremerged/peak_matrices/atac_notx_peak_matrix.tsv'
bed_df = pandas.read_csv(bed_fname, index_col=0, sep='\t')

# %%
bed_df.sort_values()

# %% [markdown]
# # Command line 1

# %%
# !python scripts/genomic_peas.py vector /home/dskola/projects/coupled_peaks/moremerged/peak_matrices/atac_notx_peak_matrix.tsv homer 7,8 --max-size 100 -o test_crds.tsv -p 1
# Out:
# 2018-Sep-04 15:31:22	Loaded 206960 genomic regions from /home/dskola/projects/coupled_peaks/moremerged/peak_matrices/atac_notx_peak_matrix.tsv
# 2018-Sep-04 15:31:22	Processing 15120 elements in chromosome chr1
# 2018-Sep-04 15:31:22		trimmed 15120 element vector to remove preceding and trailing NaNs. 15120 elements remain
# 2018-Sep-04 15:31:22		computing means of all subarrays of 15120-element vector ...
# 2018-Sep-04 15:31:30		constructing null models for regions up to size 100 ...
# 2018-Sep-04 15:31:31		computing -log pvalues ...
# 2018-Sep-04 15:31:33		applying filters ...
# 2018-Sep-04 15:31:33			minimum size: 3 ...
# 2018-Sep-04 15:31:36			maximum size: 100 ...
# 2018-Sep-04 15:31:38			maximum p-value: 1.0 ...
# 2018-Sep-04 15:31:39		minimizing product of p-values
# 2018-Sep-04 15:31:39		raising edge weights to power of 2
# 2018-Sep-04 15:31:39		computing optimum regions ...
# 2018-Sep-04 15:31:39			Found 3889 regions covering 12962 peaks
# ...
